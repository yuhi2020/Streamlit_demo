# %%
# !pip install -U streamlit streamlit-webrtc opencv-python-headless
# Out:
# ...
#      ---------------------------------------- 8.9/8.9 MB 9.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 873.4/873.4 kB 5.5 MB/s eta 0:00:00
# ...
#      --------------------------------------- 38.1/38.1 MB 11.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 164.8/164.8 kB 5.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 422.5/422.5 kB 8.8 MB/s eta 0:00:00
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...
#      ---------------------------------------- 2.5/2.5 MB 10.7 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.8/14.8 MB 10.4 MB/s eta 0:00:00
# ...
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# ...
#      ---------------------------------------- 239.4/239.4 kB ? eta 0:00:00
# ...
#      --------------------------------------- 10.7/10.7 MB 13.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 428.4/428.4 kB 27.9 MB/s eta 0:00:00
# ...

# %%
streamlit run "app.py"
# Out:
# ^C
